# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-ZZZZZ/ALP_ComSc/blob/main/First_Prensentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
shotgun = ["by15", "R90", "Krame262", "Argus"]
pistole = ["MW11", "J363", "Shorty", "L-CARL9"]
rifle = ["Type19", "Krig6", "LK24", "BP50"]
snipe = ["DLQ33", "Locus", "LW3-Tundra", "Arctic50"]
insertWeapon = "Weapon"
gun = "nothing"

weapons = [shotgun, pistole, rifle, snipe]
print("Welcome to the game")
print("You're now encountered a zombie and prepare to fight!")
print("Shotgun", "Pistole", "Rifle", "Snipe")
print("Type 1 to pick form the list and type 2 to pick your own")
choosen = int(input())
if choosen == 1:
  chose = int(input("Choose what type weapon you want (1-4) "))
  if chose == 1:
    print("You pick shotgun")
    print(shotgun)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen by15 and 2 is R90 and etc.)"))
    if gunChoice == 1:
      print("BY15 has hipfire tight pellet spread and high pellet travel range, allowing it to one-hit kill enemies at very long range. However, such tight pellet spread requires players to be accurate in order to land all pellets on enemies and avoid hitmarkers.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "by15"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print("R90 is a Belgian selective-fire, magazine-fed, 5.7mm bullpup submachine gun. It fires up to 50 5.7×28mm cartridges from the 50Rnd 5.7mm magazine. The R90 is a bullpup weapon, meaning the firing mechanism and magazine is behind the trigger.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "R90"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("KRM-262 is a pump-action shotgun. It will kill anyone with a single shot in close range. However, the damage quickly drops off.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Krame262"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("It has a tight cone of fire when fired from the hip, and has no spread when aiming down the sights (unlike other shotguns). It also enters ADS faster than average.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Argus"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == 2:
    print("You pick pistole")
    print(pistole)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen MW11 and 2 is J363 and etc.)"))
    if gunChoice == 1:
      print("MW11 is a single-action, recoil-operated, semi-automatic pistol chambered for the .45 ACP cartridge.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "MW11"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print("Designed for colder latitudes, this waterproof parka defies the elements with 8K/5K weather protection")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "J363"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("Designed as a stand alone pistol grip weapon system it includes the LMT frame for rail mounted M203. Utilizes 7″ 40mm 1:48” RH twist barrel.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Shorty"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("is a super-compact machine pistol designed as a lightweight personal defense weapon")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "L-CARL9"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == 3:
    print("You pick rifle")
    print(rifle)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen Type19 and 2 is Krig6 and etc.)"))
    if gunChoice == 1:
      print("Type 19 155 mm Wheeled Self-Propelled Howitzer is Japanese wheeled self-propelled gun. The vehicle is designed to replace Japan's inventory of FH70.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Type19"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print(" Krig 6 is an assault rifle that is primarily meant for mid-range combat, but can compete up close with a three-shot kill to the upper torso.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Krig6"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("LK24 is a well-rounded assault rifle with steady damage output, offering four shots to kill until around 20 meters. It has a very predictable recoil patern, making it a solid option for mid-long range.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "LK24"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("This fully automatic bullpup assault rifle boasts a high fire rate while remaining deadly and accurate at long range.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "BP50"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == 4:
    print("You pick snipe")
    print(snipe)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen DLQ33 and 2 is Locus and etc.)"))
    if gunChoice == 1:
      print("The DLQ33 is rather similar to the Intervention from previous games, in terms of appearance and behavior. It has great stats: good sprint speed, good ADS speed, and a full one-shot. ")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "DLQ33"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print("Locus is a bolt-action sniper rifle which has a low rate of fire, but incredible accuracy and power at long range.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Locus"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("Bolt-action sniper rifle. High damage with moderate sway. 1-shot kill to the head, upper-chest, and shoulders. Hold L while ADS to steady.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "LW3-Tundra"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("Arctic . 50 has high damage and good ADS spread at range. ")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Arctic50"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  else:
    print("Ready to fight with your fist?")
    gun = "a fist"
elif choosen == 2:
  insertWeapon = input("Name your weapon ")
  print(weapons)
  chose = int(input("Choose your weapon (1 represen shotgun and 2 is pistole and etc.)"))
  if chose == 1:
    print("You pick shotgun")
    print(shotgun)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen by15 and 2 is R90 and etc.)"))
    if gunChoice == 1:
      print("BY15 has hipfire tight pellet spread and high pellet travel range, allowing it to one-hit kill enemies at very long range. However, such tight pellet spread requires players to be accurate in order to land all pellets on enemies and avoid hitmarkers.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "by15"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print("R90 is a Belgian selective-fire, magazine-fed, 5.7mm bullpup submachine gun. It fires up to 50 5.7×28mm cartridges from the 50Rnd 5.7mm magazine. The R90 is a bullpup weapon, meaning the firing mechanism and magazine is behind the trigger.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "R90"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("KRM-262 is a pump-action shotgun. It will kill anyone with a single shot in close range. However, the damage quickly drops off.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Krame262"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("It has a tight cone of fire when fired from the hip, and has no spread when aiming down the sights (unlike other shotguns). It also enters ADS faster than average.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Argus"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == 2:
    print("You pick pistole")
    print(pistole)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen MW11 and 2 is J363 and etc.)"))
    if gunChoice == 1:
      print("MW11 is a single-action, recoil-operated, semi-automatic pistol chambered for the .45 ACP cartridge.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "MW11"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print("Designed for colder latitudes, this waterproof parka defies the elements with 8K/5K weather protection")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "J363"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("Designed as a stand alone pistol grip weapon system it includes the LMT frame for rail mounted M203. Utilizes 7″ 40mm 1:48” RH twist barrel.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Shorty"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("is a super-compact machine pistol designed as a lightweight personal defense weapon")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "L-CARL9"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == 3:
    print("You pick rifle")
    print(rifle)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen Type19 and 2 is Krig6 and etc.)"))
    if gun == 1:
      print("Type 19 155 mm Wheeled Self-Propelled Howitzer is Japanese wheeled self-propelled gun. The vehicle is designed to replace Japan's inventory of FH70.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Type19"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print(" Krig 6 is an assault rifle that is primarily meant for mid-range combat, but can compete up close with a three-shot kill to the upper torso.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Krig6"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("LK24 is a well-rounded assault rifle with steady damage output, offering four shots to kill until around 20 meters. It has a very predictable recoil patern, making it a solid option for mid-long range.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "LK24"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("This fully automatic bullpup assault rifle boasts a high fire rate while remaining deadly and accurate at long range.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "BP50"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == 4:
    print("You pick snipe")
    print(snipe)
    gunChoice = int(input("Choose what type weapon you want to view (1 represen DLQ33 and 2 is Locus and etc.)"))
    if gunChoice == 1:
      print("The DLQ33 is rather similar to the Intervention from previous games, in terms of appearance and behavior. It has great stats: good sprint speed, good ADS speed, and a full one-shot. ")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "DLQ33"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 2:
      print("Locus is a bolt-action sniper rifle which has a low rate of fire, but incredible accuracy and power at long range.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Locus"
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 3:
      print("Bolt-action sniper rifle. High damage with moderate sway. 1-shot kill to the head, upper-chest, and shoulders. Hold L while ADS to steady.")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "LW3-Tundra"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
    elif gunChoice == 4:
      print("Arctic . 50 has high damage and good ADS spread at range. ")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = "Arctic50"
      elif pickedGun == 'no':
        print("You dead man, you don't get that much time")
  elif chose == "YourWeapon":
    print("You pick snipe")
    print(insertWeapon)
    gunChoice = int(input("Choose what type weapon you want to view (Enter 1) "))
    if gunChoice == 1:
      print(insertWeapon + " is the weapon you created!")
      pickedGun = input("Do you want to pick this? ")
      if pickedGun == 'yes':
        gun = insertWeapon
      elif pickedGun =='no':
        print("You dead man, you don't get that much time")
  else:
    print("Ready to fight with your fist?")
    gun = "a fist"
else:
  print("Ready to fight with your fist?")
  gun = "a fist"
print("You have chosen " + gun)
zombieWeakness = ["R90" , "Argus" , "Type19" , "BP50" , "LW3-Tundra" , "Krame262" , "Shorty" , "Locus" ]
if gun in zombieWeakness:
  print("You killed the zombie with " + gun + " and you killed all of them!")
elif gun == "a fist":
  print("You killed the zombie with " + gun + " and you killed all of them!")
  print("You unlocked SECRET ACCOMPLISHMENT 'Trying to be Muhammad Ali?'")
else:
  print("YOU DEAD!!!")
# Out:
# Welcome to the game
# You're now encountered a zombie and prepare to fight!
# Shotgun Pistole Rifle Snipe
# Type 1 to pick form the list and type 2 to pick your own
# 1
# Choose what type weapon you want (1-4) 5
# Ready to fight with your fist?
# You have chosen a fist
# You killed the zombie with a fist and you killed all of them!
# You unlocked SECRET ACCOMPLISHMENT 'Trying to be Muhammad Ali?'
